# %%
import pandas as pd

# %%
health_edu = pd.read_csv('/Users/marijkevandergeer/Documents/GitHub/dspg23census/Health_and_Education/HE_data.csv')

# %%
health_edu
# Out:
#      Number of states within the category State/ Country  \
# 0                                     NaN        Alabama
# 1                                     NaN        Alabama
# 2                                     NaN        Alabama
# 3                                     NaN        Alabama
# 4                                     NaN        Alabama
# ..                                    ...            ...
# 146                                   NaN    Puerto Rico
# 147                                   NaN    Puerto Rico
# 148                                   NaN    Puerto Rico
# 149                                   NaN    Puerto Rico
# 150                                   NaN    Puerto Rico
#
#              Sub-categories                Tool  \
# 0                 Insurance               Table
# 1    Educational Attainment               Table
# 2    Educational Attainment  Data View/Download
# 3                Physicians  Data View/Download
# 4                 Insurance  Data View/Download
# ..                      ...                 ...
# 146                     NaN       Data Download
# 147                     NaN       Data Download
# 148           Health Counts       Data Download
# 149       School Enrollment       Data Download
# 150                     NaN       Data Download
#
#                                           Name of tool  \
# 0     Health Insurance Coverage, by State 1999 to 2011
# 1    Estimates of Educational Attainment of the Pop...
# 2    Estimates of Educational Attainment of the Pop...
# 3    Physicians by County of Licensure in Alabama: ...
# 4    Health Insurance Coverage Status by Age for Co...
# ..                                                 ...
# 146                          Dataset on public schools
# 147                           Post-secondary education
# 148                     Annual vital statistics report
# 149      Public school enrollment by grade and by year
# 150         Number of students below the poverty level
#
#                   Variables Used (list all that apply)  \
# 0    All People, Not Covered, Covered by Private or...
# 1    Percent high school graduate or higher, Percen...
# 2    Percent high school graduate or higher, Percen...
# 3                               Total In-State Doctors
# 4    Female, Male; Under 6 years, 6 to 17 years, 18...
# ..                                                 ...
# 146                                                NaN
# 147                                                NaN
# 148  births, basic mortality, mortality from multip...
# 149                                                NaN
# 150                                                NaN
#
#                       Geographic Levels Data Sources-Census  \
# 0                                 State                 CPS
# 1                                County                 ACS
# 2    City/Town, Census designated place                 ACS
# 3                                County                 NaN
# 4                                County                 ACS
# ..                                  ...                 ...
# 146                                 NaN                 NaN
# 147                                 NaN                 NaN
# 148                                 NaN                 NaN
# 149                                 NaN                 NaN
# 150                                 NaN                 NaN
#
#                          Data Sources-Non Census Direct links to Census  \
# 0                                            NaN                      N
# 1                                            NaN                      N
# 2                                            NaN                      N
# 3           Alabama Medical Licensure Commission                      N
# 4                                            NaN                      N
# ..                                           ...                    ...
# 146    National Center for Education Statistics                       N
# 147    National Center for Education Statistics                       N
# 148  Centers for Disease Control and Prevention                       N
# 149                      Department of Education                      N
# 150                      Department of Education                      N
#
#     Census link Frequency  Age of data Unnamed: 13 Historical data  \
# 0             N       NaN       2011.0         NaN               Y
# 1             N       NaN       2013.0         NaN               N
# 2             N       NaN       2013.0         NaN               N
# 3             N       NaN       2010.0         NaN               N
# 4             N       NaN       2009.0         NaN               N
# ..          ...       ...          ...         ...             ...
# 146           N       NaN       2008.0         NaN               Y
# 147           N       NaN       2010.0         NaN               N
# 148           N       NaN       2015.0         NaN               Y
# 149           N       NaN       2019.0         NaN               N
# 150           N       NaN       2014.0         NaN               N
#
#     Data Linkage  Citation                                              Notes
# 0            NaN       NaN                    Contains tables for every state
# 1            NaN       NaN                                                NaN
# 2            NaN       NaN                                                NaN
# 3            NaN       NaN                                                NaN
# 4            NaN       NaN  For Alabama counties with 65,000 population or...
# ..           ...       ...                                                ...
# 146          NaN       NaN                                                NaN
# 147          NaN       NaN                                                NaN
# 148          NaN       NaN                                                NaN
# 149          NaN       NaN                                                NaN
# 150          NaN       NaN                                                NaN
#
# [151 rows x 18 columns]
