# %%
import pandas as pd

# %%
housing = pd.read_csv('/Users/marijkevandergeer/Documents/GitHub/dspg23census/Housing/Housing_data.csv')

# %%
housing
# Out:
#      Number of states within the category State/ Country  \
# 0                                     NaN        Alabama
# 1                                     NaN        Alabama
# 2                                     NaN         Alaska
# 3                                     NaN         Alaska
# 4                                     NaN         Alaska
# ..                                    ...            ...
# 161                                   NaN           Guam
# 162                                   NaN           Guam
# 163                                   NaN           Guam
# 164                                   NaN    Puerto Rico
# 165                                   NaN    Puerto Rico
#
#               Sub-categories                Tool  \
# 0                  Estimates      Table Download
# 1                  Estimates      Table Download
# 2             Housing Prices  Data Visualization
# 3             Housing Prices  Data Visualization
# ...
